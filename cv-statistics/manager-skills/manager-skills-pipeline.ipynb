# %% [markdown]
# This's notebook for CV statistics

# %%
import os
import sys
import operator
import numpy as np
import pandas as pd
from scipy import sparse
import xgboost as xgb
import random
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
#input data
train_df=pd.read_json('../../input/train.json')
test_df=pd.read_json('../../input/test.json')
image_time=pd.read_csv('../../input/listing_image_time.csv')

# %%
train_df=train_df.merge(image_time, left_on='listing_id', right_on='Listing_Id', how='left')
test_df=test_df.merge(image_time, left_on='listing_id', right_on='Listing_Id', how='left')

# %% [markdown]
# ## Now add some basic feature.
# - price per bed
# - bedroom + bathroom
# - num of photos
# - num of features
# - len of descriptions
# - time created

# %%
#basic features
train_df["price_t"] =train_df["price"]/train_df["bedrooms"]
test_df["price_t"] = test_df["price"]/test_df["bedrooms"] 
train_df["room_sum"] = train_df["bedrooms"]+train_df["bathrooms"] 
test_df["room_sum"] = test_df["bedrooms"]+test_df["bathrooms"] 

# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# created
train_df["created"] = pd.to_datetime(train_df["created"])
train_df["created_month"] = train_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
train_df["day_of_week"] = train_df["created"].dt.weekday
train_df["created_hour"] = train_df["created"].dt.hour

test_df["created"] = pd.to_datetime(test_df["created"])
test_df["created_month"] = test_df["created"].dt.month
test_df["created_day"] = test_df["created"].dt.day
test_df["day_of_week"] = test_df["created"].dt.weekday
test_df["created_hour"] = test_df["created"].dt.hour


features_to_use=["bathrooms", "bedrooms", "latitude", "longitude", "price","price_t","num_photos", "num_features", "num_description_words","listing_id","created_month","created_day","created_hour","day_of_week", "time_stamp"]

# %% [markdown]
# ## Define XGB function, it come from "XGB starter in python" by SRK

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=4000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.03
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %% [markdown]
# ## CV statistics, only change here
# The following code chunk contributes to the construction of the frequency-ratio table for each unique manager_id in the training data. Effect of the cross-validation is considered when constructing.

# %%
# for 5-fold cv engineering the interest_level ratio for each manager_id
index=list(range(train_df.shape[0]))
random.shuffle(index)
a=[np.nan]*len(train_df)
b=[np.nan]*len(train_df)
c=[np.nan]*len(train_df)

for i in range(5):
    building_level={}
    for j in train_df['manager_id'].values:
        building_level[j]=[0,0,0]
    test_index=index[int((i*train_df.shape[0])/5):int(((i+1)*train_df.shape[0])/5)]
    train_index=list(set(index).difference(test_index))
    for j in train_index:
        temp=train_df.iloc[j]
        if temp['interest_level']=='low':
            building_level[temp['manager_id']][0]+=1
        if temp['interest_level']=='medium':
            building_level[temp['manager_id']][1]+=1
        if temp['interest_level']=='high':
            building_level[temp['manager_id']][2]+=1
    for j in test_index:
        temp=train_df.iloc[j]
        if sum(building_level[temp['manager_id']])!=0:
            a[j]=building_level[temp['manager_id']][0]*1.0/sum(building_level[temp['manager_id']])
            b[j]=building_level[temp['manager_id']][1]*1.0/sum(building_level[temp['manager_id']])
            c[j]=building_level[temp['manager_id']][2]*1.0/sum(building_level[temp['manager_id']])
train_df['manager_level_low']=a
train_df['manager_level_medium']=b
train_df['manager_level_high']=c


# for test data engineering the interest_level ratio for each manager_id
a=[]
b=[]
c=[]
building_level={}
for j in train_df['manager_id'].values:
    building_level[j]=[0,0,0]
for j in range(train_df.shape[0]):
    temp=train_df.iloc[j]
    if temp['interest_level']=='low':
        building_level[temp['manager_id']][0]+=1
    if temp['interest_level']=='medium':
        building_level[temp['manager_id']][1]+=1
    if temp['interest_level']=='high':
        building_level[temp['manager_id']][2]+=1

for i in test_df['manager_id'].values:
    if i not in building_level.keys():
        a.append(np.nan)
        b.append(np.nan)
        c.append(np.nan)
    else:
        a.append(building_level[i][0]*1.0/sum(building_level[i]))
        b.append(building_level[i][1]*1.0/sum(building_level[i]))
        c.append(building_level[i][2]*1.0/sum(building_level[i]))
test_df['manager_level_low']=a
test_df['manager_level_medium']=b
test_df['manager_level_high']=c

features_to_use.append('manager_level_low') 
features_to_use.append('manager_level_medium') 
features_to_use.append('manager_level_high')

# %% [markdown]
# ### The following code chunk discuss the creation of a pipline for the manager_skill feature

# %%
#Our feature construction class will inherit from these two base classes of sklearn.
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin

class manager_skill(BaseEstimator, TransformerMixin):
    """
    Adds the column "manager_skill" to the dataset, based on the Kaggle kernel
    "Improve Perfomances using Manager features" by den3b. The function should
    be usable in scikit-learn pipelines.
    
    Parameters
    ----------
    threshold : Minimum count of rental listings a manager must have in order
                to get his "own" score, otherwise the mean is assigned.

    Attributes
    ----------
    mapping : pandas dataframe
        contains the manager_skill per manager id.
        
    mean_skill : float
        The mean skill of managers with at least as many listings as the 
        threshold.
    """
    def __init__(self, threshold = 5):
        
        self.threshold = threshold
        
    def _reset(self):
        """Reset internal data-dependent state of the scaler, if necessary.
        
        __init__ parameters are not touched.
        """
        # Checking one attribute is enough, becase they are all set together
        # in fit        
        if hasattr(self, 'mapping_'):
            
            self.mapping_ = {}
            self.mean_skill_ = 0.0
        
    def fit(self, X,y):
        """Compute the skill values per manager for later use.
        
        Parameters
        ----------
        X : pandas dataframe, shape [n_samples, n_features]
            The rental data. It has to contain a column named "manager_id".
            
        y : pandas series or numpy array, shape [n_samples]
            The corresponding target values with encoding:
            low: 0.0
            medium: 1.0
            high: 2.0
        """        
        self._reset()
        
        temp = pd.concat([X.manager_id,pd.get_dummies(y)], axis = 1).groupby('manager_id').mean()
        temp.columns = ['low_frac', 'medium_frac', 'high_frac']
        temp['count'] = X.groupby('manager_id').count().iloc[:,1]
        
#        print(temp.head())
        
        temp['manager_skill'] = temp['high_frac']*2 + temp['medium_frac']
        
        mean = temp.loc[temp['count'] >= self.threshold, 'manager_skill'].mean()
        
        temp.loc[temp['count'] < self.threshold, 'manager_skill'] = mean
        
        self.mapping_ = temp[['manager_skill']]
        self.mean_skill_ = mean
            
        return self
        
    def transform(self, X):
        """Add manager skill to a new matrix.
        
        Parameters
        ----------
        X : pandas dataframe, shape [n_samples, n_features]
            Input data, has to contain "manager_id".
        """        
        X = pd.merge(left = X, right = self.mapping_, how = 'left', left_on = 'manager_id', right_index = True)
        X['manager_skill'].fillna(self.mean_skill_, inplace = True)
        
        return X

# %% [markdown]
# You can use this method just like any other scikit-learn transformation method:

# %%
#Initialize the object
trans = manager_skill()
#You can do fit and transform in one step:
train_df_transform = trans.fit_transform(train_df.drop(['interest_level'], axis=1), train_df['interest_level'])
train_df['manager_skill'] = train_df_transform.manager_skill
#Apply to test data
test_df = trans.transform(test_df)

# %% [markdown]
# ## High cardinality categorical features
# For the code chunk below, categorical features are transfered into numerical values. Unique categorical data is represented with unique numerical values, and the total level of the data defines the range of the corresponding numerical feature.

# %%
categorical = ["display_address", "manager_id", "building_id", "street_address"]
for f in categorical:
        if train_df[f].dtype=='object':
#            print(f, train_df[f].dtype)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %% [markdown]
# ## TF-IDF encoding of the "features" in data
#
# This is actually only a term-document sparse matrix

# %%
train_df['features'] = train_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
test_df['features'] = test_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
print(train_df["features"].head())
tfidf = CountVectorizer(stop_words='english', max_features=200)
tr_sparse = tfidf.fit_transform(train_df["features"])
te_sparse = tfidf.transform(test_df["features"])
# Out:
# 0
# 1    Doorman Elevator Fitness_Center Cats_Allowed D...
# 2    Laundry_In_Building Dishwasher Hardwood_Floors...
# 3                               Hardwood_Floors No_Fee
# 4                                              Pre-War
# Name: features, dtype: object

# %%
#these_features = [f for f in features_to_use if f not in ['manager_skill']]
these_features = features_to_use
train_X = sparse.hstack([train_df[these_features], tr_sparse]).tocsr()
test_X = sparse.hstack([test_df[these_features], te_sparse]).tocsr()

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))
print(train_X.shape, test_X.shape)
# Out:
# (49352, 222) (74659, 222)

# %% [markdown]
# Without CV statistic,to score get 0.5480 by SRK. And CV statistic get 0.5346 In fact ,you
# need to turn down the learning rate and turn up run_num

# %%
cv_scores = []
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(train_X.shape[0])):
        dev_X, val_X = train_X[dev_index,:], train_X[val_index,:]
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# [0]	train-mlogloss:1.07762	test-mlogloss:1.07815
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:1.05767	test-mlogloss:1.05865
# [2]	train-mlogloss:1.03976	test-mlogloss:1.04113
# [3]	train-mlogloss:1.02182	test-mlogloss:1.02368
# [4]	train-mlogloss:1.00496	test-mlogloss:1.00721
# [5]	train-mlogloss:0.988857	test-mlogloss:0.991477
# [6]	train-mlogloss:0.973392	test-mlogloss:0.976483
# [7]	train-mlogloss:0.958443	test-mlogloss:0.96198
# [8]	train-mlogloss:0.944235	test-mlogloss:0.948179
# [9]	train-mlogloss:0.930773	test-mlogloss:0.935124
# [10]	train-mlogloss:0.917545	test-mlogloss:0.922328
# [11]	train-mlogloss:0.904902	test-mlogloss:0.910215
# [12]	train-mlogloss:0.892858	test-mlogloss:0.898525
# [13]	train-mlogloss:0.881107	test-mlogloss:0.887091
# [14]	train-mlogloss:0.869982	test-mlogloss:0.876421
# [15]	train-mlogloss:0.859418	test-mlogloss:0.866212
# [16]	train-mlogloss:0.84915	test-mlogloss:0.85637
# [17]	train-mlogloss:0.839466	test-mlogloss:0.847095
# [18]	train-mlogloss:0.829865	test-mlogloss:0.837808
# [19]	train-mlogloss:0.820954	test-mlogloss:0.829208
# [20]	train-mlogloss:0.811989	test-mlogloss:0.82055
# [21]	train-mlogloss:0.80333	test-mlogloss:0.81239
# [22]	train-mlogloss:0.794975	test-mlogloss:0.804568
# [23]	train-mlogloss:0.786914	test-mlogloss:0.796995
# [24]	train-mlogloss:0.779089	test-mlogloss:0.789509
# [425]	train-mlogloss:0.423342	test-mlogloss:0.529539
# [426]	train-mlogloss:0.423124	test-mlogloss:0.5295
# [427]	train-mlogloss:0.422943	test-mlogloss:0.52948
# [428]	train-mlogloss:0.422784	test-mlogloss:0.529442
# [429]	train-mlogloss:0.422521	test-mlogloss:0.52932
# [430]	train-mlogloss:0.422193	test-mlogloss:0.529199
# [431]	train-mlogloss:0.42195	test-mlogloss:0.529189
# [432]	train-mlogloss:0.421788	test-mlogloss:0.529159
# [433]	train-mlogloss:0.421522	test-mlogloss:0.529128
# [434]	train-mlogloss:0.421278	test-mlogloss:0.529091
# [435]	train-mlogloss:0.421107	test-mlogloss:0.529046
# [436]	train-mlogloss:0.420835	test-mlogloss:0.529016
# [437]	train-mlogloss:0.420723	test-mlogloss:0.529007
# [438]	train-mlogloss:0.420405	test-mlogloss:0.528931
# [439]	train-mlogloss:0.420134	test-mlogloss:0.528841
# [440]	train-mlogloss:0.419903	test-mlogloss:0.528771
# [441]	train-mlogloss:0.419683	test-mlogloss:0.52876
# [442]	train-mlogloss:0.419485	test-mlogloss:0.528728
# [443]	train-mlogloss:0.419223	test-mlogloss:0.528693
# [444]	train-mlogloss:0.419001	test-mlogloss:0.528659
# [445]	train-mlogloss:0.418852	test-mlogloss:0.528635
# [446]	train-mlogloss:0.418649	test-mlogloss:0.528639
# [447]	train-mlogloss:0.418396	test-mlogloss:0.52862
# [448]	train-mlogloss:0.418115	test-mlogloss:0.528542
# [449]	train-mlogloss:0.417933	test-mlogloss:0.528521
# [450]	train-mlogloss:0.417675	test-mlogloss:0.528489
# [451]	train-mlogloss:0.417419	test-mlogloss:0.52841
# [452]	train-mlogloss:0.417212	test-mlogloss:0.528374
# [453]	train-mlogloss:0.416912	test-mlogloss:0.528335
# [454]	train-mlogloss:0.416704	test-mlogloss:0.528331
# [455]	train-mlogloss:0.416442	test-mlogloss:0.528314
# [456]	train-mlogloss:0.416236	test-mlogloss:0.528291
# [457]	train-mlogloss:0.41603	test-mlogloss:0.528254
# [458]	train-mlogloss:0.415752	test-mlogloss:0.528206
# [459]	train-mlogloss:0.415509	test-mlogloss:0.52818
# [460]	train-mlogloss:0.415317	test-mlogloss:0.528141
# [461]	train-mlogloss:0.41506	test-mlogloss:0.528111
# [462]	train-mlogloss:0.414862	test-mlogloss:0.528088
# [463]	train-mlogloss:0.414635	test-mlogloss:0.528047
# [464]	train-mlogloss:0.414369	test-mlogloss:0.52796
# [465]	train-mlogloss:0.414178	test-mlogloss:0.527942
# [466]	train-mlogloss:0.413971	test-mlogloss:0.527887
# [467]	train-mlogloss:0.413747	test-mlogloss:0.527825
# [468]	train-mlogloss:0.413564	test-mlogloss:0.527782
# [469]	train-mlogloss:0.413283	test-mlogloss:0.527752
# [470]	train-mlogloss:0.413059	test-mlogloss:0.527715
# [471]	train-mlogloss:0.412878	test-mlogloss:0.527691
# [472]	train-mlogloss:0.412648	test-mlogloss:0.527648
# [473]	train-mlogloss:0.412443	test-mlogloss:0.527615
# [474]	train-mlogloss:0.412231	test-mlogloss:0.527611
# [475]	train-mlogloss:0.41192	test-mlogloss:0.527556
# [476]	train-mlogloss:0.411689	test-mlogloss:0.527541
# [477]	train-mlogloss:0.411482	test-mlogloss:0.52748
# [478]	train-mlogloss:0.411317	test-mlogloss:0.527454
# [479]	train-mlogloss:0.411066	test-mlogloss:0.527419
# [480]	train-mlogloss:0.410925	test-mlogloss:0.527402
# [481]	train-mlogloss:0.410701	test-mlogloss:0.527361
# [482]	train-mlogloss:0.410454	test-mlogloss:0.527286
# [483]	train-mlogloss:0.410291	test-mlogloss:0.527256
# [484]	train-mlogloss:0.410067	test-mlogloss:0.527208
# [485]	train-mlogloss:0.409902	test-mlogloss:0.527215
# [486]	train-mlogloss:0.409613	test-mlogloss:0.52719
# [487]	train-mlogloss:0.409484	test-mlogloss:0.527171
# [488]	train-mlogloss:0.409204	test-mlogloss:0.527137
# [489]	train-mlogloss:0.409007	test-mlogloss:0.527111
# [490]	train-mlogloss:0.408837	test-mlogloss:0.527044
# [491]	train-mlogloss:0.408705	test-mlogloss:0.526993
# [492]	train-mlogloss:0.408425	test-mlogloss:0.526928
# [493]	train-mlogloss:0.408174	test-mlogloss:0.526847
# [494]	train-mlogloss:0.407944	test-mlogloss:0.526787
# [495]	train-mlogloss:0.407713	test-mlogloss:0.526688
# [496]	train-mlogloss:0.407498	test-mlogloss:0.526698
# [497]	train-mlogloss:0.40729	test-mlogloss:0.526642
# [498]	train-mlogloss:0.407145	test-mlogloss:0.526606
# [499]	train-mlogloss:0.406935	test-mlogloss:0.526586
# [500]	train-mlogloss:0.406727	test-mlogloss:0.526577
# [501]	train-mlogloss:0.406482	test-mlogloss:0.526553
# [502]	train-mlogloss:0.406235	test-mlogloss:0.526518
# [503]	train-mlogloss:0.406045	test-mlogloss:0.526475
# [504]	train-mlogloss:0.405864	test-mlogloss:0.526463
# [505]	train-mlogloss:0.40571	test-mlogloss:0.526456
# [506]	train-mlogloss:0.405436	test-mlogloss:0.526399
# [507]	train-mlogloss:0.405217	test-mlogloss:0.526384
# [508]	train-mlogloss:0.40499	test-mlogloss:0.526329
# [509]	train-mlogloss:0.404832	test-mlogloss:0.526291
# [510]	train-mlogloss:0.404645	test-mlogloss:0.526252
# [511]	train-mlogloss:0.404503	test-mlogloss:0.526248
# [512]	train-mlogloss:0.404309	test-mlogloss:0.526208
# [513]	train-mlogloss:0.404075	test-mlogloss:0.526156
# [514]	train-mlogloss:0.403898	test-mlogloss:0.526101
# [515]	train-mlogloss:0.403745	test-mlogloss:0.526084
# [516]	train-mlogloss:0.403553	test-mlogloss:0.526074
# [517]	train-mlogloss:0.40336	test-mlogloss:0.526053
# [518]	train-mlogloss:0.403152	test-mlogloss:0.525988
# [519]	train-mlogloss:0.402987	test-mlogloss:0.525958
# [520]	train-mlogloss:0.402798	test-mlogloss:0.525939
# [521]	train-mlogloss:0.402615	test-mlogloss:0.525904
# [522]	train-mlogloss:0.402405	test-mlogloss:0.525869
# [523]	train-mlogloss:0.402249	test-mlogloss:0.525862
# [524]	train-mlogloss:0.402067	test-mlogloss:0.525827
# [525]	train-mlogloss:0.401869	test-mlogloss:0.52581
# [626]	train-mlogloss:0.38242	test-mlogloss:0.523559
# [627]	train-mlogloss:0.382306	test-mlogloss:0.523568
# [628]	train-mlogloss:0.382134	test-mlogloss:0.523534
# [629]	train-mlogloss:0.381986	test-mlogloss:0.523543
# [630]	train-mlogloss:0.381795	test-mlogloss:0.523524
# [631]	train-mlogloss:0.381644	test-mlogloss:0.523492
# [632]	train-mlogloss:0.381454	test-mlogloss:0.523461
# [633]	train-mlogloss:0.381324	test-mlogloss:0.523484
# [634]	train-mlogloss:0.38118	test-mlogloss:0.523478
# [635]	train-mlogloss:0.38099	test-mlogloss:0.523415
# [636]	train-mlogloss:0.380824	test-mlogloss:0.523388
# [637]	train-mlogloss:0.380578	test-mlogloss:0.52338
# [638]	train-mlogloss:0.380309	test-mlogloss:0.523352
# [639]	train-mlogloss:0.380105	test-mlogloss:0.523355
# [640]	train-mlogloss:0.37993	test-mlogloss:0.523321
# [641]	train-mlogloss:0.379787	test-mlogloss:0.523309
# [642]	train-mlogloss:0.37966	test-mlogloss:0.523313
# [643]	train-mlogloss:0.379463	test-mlogloss:0.523323
# [644]	train-mlogloss:0.379226	test-mlogloss:0.523277
# [645]	train-mlogloss:0.379092	test-mlogloss:0.523277
# [646]	train-mlogloss:0.378927	test-mlogloss:0.523246
# [647]	train-mlogloss:0.378775	test-mlogloss:0.52319
# [648]	train-mlogloss:0.378609	test-mlogloss:0.523207
# [649]	train-mlogloss:0.378477	test-mlogloss:0.523211
# [650]	train-mlogloss:0.378326	test-mlogloss:0.523168
# [651]	train-mlogloss:0.378159	test-mlogloss:0.523153
# [652]	train-mlogloss:0.377972	test-mlogloss:0.523143
# [653]	train-mlogloss:0.377801	test-mlogloss:0.523167
# [654]	train-mlogloss:0.37758	test-mlogloss:0.523174
# [655]	train-mlogloss:0.377389	test-mlogloss:0.523191
# [656]	train-mlogloss:0.377171	test-mlogloss:0.52322
# [657]	train-mlogloss:0.377051	test-mlogloss:0.523202
# [658]	train-mlogloss:0.376901	test-mlogloss:0.523194
# [659]	train-mlogloss:0.376747	test-mlogloss:0.52321
# [660]	train-mlogloss:0.37664	test-mlogloss:0.523206
# [661]	train-mlogloss:0.376398	test-mlogloss:0.523222
# [662]	train-mlogloss:0.37617	test-mlogloss:0.523179
# [663]	train-mlogloss:0.375996	test-mlogloss:0.523109
# [664]	train-mlogloss:0.375779	test-mlogloss:0.523063
# [665]	train-mlogloss:0.37559	test-mlogloss:0.523043
# [666]	train-mlogloss:0.375425	test-mlogloss:0.523035
# [667]	train-mlogloss:0.375151	test-mlogloss:0.523033
# [668]	train-mlogloss:0.374983	test-mlogloss:0.523043
# [669]	train-mlogloss:0.374811	test-mlogloss:0.523031
# [670]	train-mlogloss:0.374624	test-mlogloss:0.522995
# [671]	train-mlogloss:0.374527	test-mlogloss:0.522977
# [672]	train-mlogloss:0.374356	test-mlogloss:0.522994
# [673]	train-mlogloss:0.374183	test-mlogloss:0.522978
# [674]	train-mlogloss:0.373972	test-mlogloss:0.522953
# [675]	train-mlogloss:0.373777	test-mlogloss:0.522938
# [676]	train-mlogloss:0.373604	test-mlogloss:0.522915
# [677]	train-mlogloss:0.373442	test-mlogloss:0.522896
# [678]	train-mlogloss:0.373252	test-mlogloss:0.522924
# [679]	train-mlogloss:0.373056	test-mlogloss:0.522919
# [680]	train-mlogloss:0.372916	test-mlogloss:0.522884
# [681]	train-mlogloss:0.372737	test-mlogloss:0.522854
# [682]	train-mlogloss:0.372571	test-mlogloss:0.522888
# [683]	train-mlogloss:0.372388	test-mlogloss:0.522931
# [684]	train-mlogloss:0.372202	test-mlogloss:0.522895
# [685]	train-mlogloss:0.372021	test-mlogloss:0.522896
# [686]	train-mlogloss:0.371908	test-mlogloss:0.522863
# [687]	train-mlogloss:0.371762	test-mlogloss:0.522835
# [688]	train-mlogloss:0.371585	test-mlogloss:0.522817
# [689]	train-mlogloss:0.371348	test-mlogloss:0.522784
# [690]	train-mlogloss:0.371135	test-mlogloss:0.522781
# [691]	train-mlogloss:0.37093	test-mlogloss:0.52275
# [692]	train-mlogloss:0.370778	test-mlogloss:0.522731
# [693]	train-mlogloss:0.370631	test-mlogloss:0.522721
# [694]	train-mlogloss:0.370482	test-mlogloss:0.522711
# [695]	train-mlogloss:0.370354	test-mlogloss:0.522739
# [696]	train-mlogloss:0.37018	test-mlogloss:0.522732
# [697]	train-mlogloss:0.369996	test-mlogloss:0.522731
# [698]	train-mlogloss:0.369844	test-mlogloss:0.522707
# [699]	train-mlogloss:0.369568	test-mlogloss:0.522683
# [700]	train-mlogloss:0.369342	test-mlogloss:0.52267
# [701]	train-mlogloss:0.369144	test-mlogloss:0.522681
# [702]	train-mlogloss:0.368933	test-mlogloss:0.522678
# [703]	train-mlogloss:0.368775	test-mlogloss:0.522692
# [704]	train-mlogloss:0.368619	test-mlogloss:0.522655
# [705]	train-mlogloss:0.36845	test-mlogloss:0.522661
# [706]	train-mlogloss:0.368225	test-mlogloss:0.522642
# [707]	train-mlogloss:0.368043	test-mlogloss:0.522623
# [708]	train-mlogloss:0.36782	test-mlogloss:0.522582
# [709]	train-mlogloss:0.367644	test-mlogloss:0.522561
# [710]	train-mlogloss:0.367529	test-mlogloss:0.522579
# [711]	train-mlogloss:0.36734	test-mlogloss:0.522563
# [712]	train-mlogloss:0.367185	test-mlogloss:0.522563
# [713]	train-mlogloss:0.367014	test-mlogloss:0.52256
# [714]	train-mlogloss:0.366901	test-mlogloss:0.522563
# [715]	train-mlogloss:0.366756	test-mlogloss:0.522547
# [716]	train-mlogloss:0.366535	test-mlogloss:0.522565
# [717]	train-mlogloss:0.366385	test-mlogloss:0.52256
# [718]	train-mlogloss:0.366176	test-mlogloss:0.522553
# [719]	train-mlogloss:0.365959	test-mlogloss:0.522542
# [720]	train-mlogloss:0.365818	test-mlogloss:0.522542
# [721]	train-mlogloss:0.3657	test-mlogloss:0.522563
# [722]	train-mlogloss:0.365519	test-mlogloss:0.522554
# [723]	train-mlogloss:0.365348	test-mlogloss:0.522532
# [724]	train-mlogloss:0.365182	test-mlogloss:0.52254
# [725]	train-mlogloss:0.36501	test-mlogloss:0.522559
# [726]	train-mlogloss:0.364843	test-mlogloss:0.522544
# [727]	train-mlogloss:0.364706	test-mlogloss:0.52251
# [728]	train-mlogloss:0.364563	test-mlogloss:0.522465
# [729]	train-mlogloss:0.364371	test-mlogloss:0.522449
# [730]	train-mlogloss:0.364141	test-mlogloss:0.522442
# [731]	train-mlogloss:0.363962	test-mlogloss:0.522402
# [732]	train-mlogloss:0.363805	test-mlogloss:0.522419
# [733]	train-mlogloss:0.363632	test-mlogloss:0.522388
# [734]	train-mlogloss:0.36346	test-mlogloss:0.522376
# [735]	train-mlogloss:0.363249	test-mlogloss:0.522336
# [736]	train-mlogloss:0.363041	test-mlogloss:0.522326
# [737]	train-mlogloss:0.362819	test-mlogloss:0.52231
# [738]	train-mlogloss:0.362666	test-mlogloss:0.522313
# [739]	train-mlogloss:0.362509	test-mlogloss:0.522269
# [740]	train-mlogloss:0.362334	test-mlogloss:0.522275
# [741]	train-mlogloss:0.362173	test-mlogloss:0.522303
# [742]	train-mlogloss:0.361996	test-mlogloss:0.522299
# [743]	train-mlogloss:0.361837	test-mlogloss:0.522283
# [744]	train-mlogloss:0.361754	test-mlogloss:0.522272
# [745]	train-mlogloss:0.361604	test-mlogloss:0.522248
# [746]	train-mlogloss:0.36142	test-mlogloss:0.522223
# [747]	train-mlogloss:0.361195	test-mlogloss:0.522208
# [748]	train-mlogloss:0.361023	test-mlogloss:0.522213
# [749]	train-mlogloss:0.360849	test-mlogloss:0.522221
# [750]	train-mlogloss:0.360721	test-mlogloss:0.52222
# [751]	train-mlogloss:0.360545	test-mlogloss:0.522213
# [752]	train-mlogloss:0.36039	test-mlogloss:0.522225
# [753]	train-mlogloss:0.360233	test-mlogloss:0.522191
# [754]	train-mlogloss:0.360055	test-mlogloss:0.52222
# [755]	train-mlogloss:0.359875	test-mlogloss:0.522231
# [756]	train-mlogloss:0.359757	test-mlogloss:0.522224
# [757]	train-mlogloss:0.359609	test-mlogloss:0.522211
# [758]	train-mlogloss:0.359438	test-mlogloss:0.522204
# [759]	train-mlogloss:0.35926	test-mlogloss:0.522202
# [760]	train-mlogloss:0.359067	test-mlogloss:0.522219
# [761]	train-mlogloss:0.358927	test-mlogloss:0.522209
# [762]	train-mlogloss:0.358752	test-mlogloss:0.522216
# [763]	train-mlogloss:0.358566	test-mlogloss:0.522228
# [764]	train-mlogloss:0.358409	test-mlogloss:0.522247
# [765]	train-mlogloss:0.358259	test-mlogloss:0.522217
# [766]	train-mlogloss:0.358062	test-mlogloss:0.522216
# [767]	train-mlogloss:0.357889	test-mlogloss:0.522235
# [768]	train-mlogloss:0.357681	test-mlogloss:0.522232
# [769]	train-mlogloss:0.357546	test-mlogloss:0.522228
# [770]	train-mlogloss:0.357378	test-mlogloss:0.522184
# [771]	train-mlogloss:0.357233	test-mlogloss:0.522176
# [772]	train-mlogloss:0.357063	test-mlogloss:0.522221
# [773]	train-mlogloss:0.356899	test-mlogloss:0.522237
# [774]	train-mlogloss:0.35674	test-mlogloss:0.522242
# [775]	train-mlogloss:0.356562	test-mlogloss:0.522245
# [776]	train-mlogloss:0.356391	test-mlogloss:0.522244
# [777]	train-mlogloss:0.356221	test-mlogloss:0.522232
# [778]	train-mlogloss:0.356017	test-mlogloss:0.522216
# [779]	train-mlogloss:0.355817	test-mlogloss:0.522201
# [780]	train-mlogloss:0.355613	test-mlogloss:0.522186
# [781]	train-mlogloss:0.355464	test-mlogloss:0.522179
# [782]	train-mlogloss:0.355292	test-mlogloss:0.522158
# [783]	train-mlogloss:0.355114	test-mlogloss:0.522144
# [784]	train-mlogloss:0.354958	test-mlogloss:0.522128
# [785]	train-mlogloss:0.354793	test-mlogloss:0.52212
# [786]	train-mlogloss:0.354629	test-mlogloss:0.522101
# [787]	train-mlogloss:0.354546	test-mlogloss:0.522112
# [788]	train-mlogloss:0.35439	test-mlogloss:0.522113
# [789]	train-mlogloss:0.354194	test-mlogloss:0.522126
# [790]	train-mlogloss:0.354001	test-mlogloss:0.522084
# [791]	train-mlogloss:0.35381	test-mlogloss:0.522066
# [792]	train-mlogloss:0.353627	test-mlogloss:0.522063
# [793]	train-mlogloss:0.353473	test-mlogloss:0.522065
# [794]	train-mlogloss:0.353353	test-mlogloss:0.522033
# [795]	train-mlogloss:0.353224	test-mlogloss:0.522049
# [796]	train-mlogloss:0.353093	test-mlogloss:0.522034
# [797]	train-mlogloss:0.352905	test-mlogloss:0.522039
# [798]	train-mlogloss:0.352684	test-mlogloss:0.522055
# [799]	train-mlogloss:0.352535	test-mlogloss:0.522024
# [800]	train-mlogloss:0.352383	test-mlogloss:0.522017
# [801]	train-mlogloss:0.352239	test-mlogloss:0.522038
# [802]	train-mlogloss:0.352058	test-mlogloss:0.522016
# [803]	train-mlogloss:0.351857	test-mlogloss:0.522005
# [804]	train-mlogloss:0.351693	test-mlogloss:0.521992
# [805]	train-mlogloss:0.351503	test-mlogloss:0.521951
# [806]	train-mlogloss:0.35132	test-mlogloss:0.521917
# [807]	train-mlogloss:0.35118	test-mlogloss:0.521902
# [808]	train-mlogloss:0.351035	test-mlogloss:0.521894
# [809]	train-mlogloss:0.350887	test-mlogloss:0.521904
# [810]	train-mlogloss:0.350749	test-mlogloss:0.52187
# [811]	train-mlogloss:0.350587	test-mlogloss:0.521847
# [812]	train-mlogloss:0.350439	test-mlogloss:0.521856
# [813]	train-mlogloss:0.350304	test-mlogloss:0.52182
# [814]	train-mlogloss:0.350127	test-mlogloss:0.52181
# [815]	train-mlogloss:0.349966	test-mlogloss:0.52183
# [816]	train-mlogloss:0.34978	test-mlogloss:0.521795
# [817]	train-mlogloss:0.349685	test-mlogloss:0.521792
# [818]	train-mlogloss:0.34954	test-mlogloss:0.521774
# [819]	train-mlogloss:0.349385	test-mlogloss:0.521818
# [820]	train-mlogloss:0.349275	test-mlogloss:0.521779
# [821]	train-mlogloss:0.349128	test-mlogloss:0.521772
# [822]	train-mlogloss:0.348933	test-mlogloss:0.521755
# [823]	train-mlogloss:0.348733	test-mlogloss:0.521792
# [824]	train-mlogloss:0.348563	test-mlogloss:0.521794
# [825]	train-mlogloss:0.348391	test-mlogloss:0.521771
# [876]	train-mlogloss:0.340465	test-mlogloss:0.521331
# [877]	train-mlogloss:0.340326	test-mlogloss:0.521326
# [878]	train-mlogloss:0.340125	test-mlogloss:0.521365
# [879]	train-mlogloss:0.339986	test-mlogloss:0.521352
# [880]	train-mlogloss:0.339772	test-mlogloss:0.521332
# [881]	train-mlogloss:0.339651	test-mlogloss:0.521312
# [882]	train-mlogloss:0.339522	test-mlogloss:0.521297
# [883]	train-mlogloss:0.339396	test-mlogloss:0.521278
# [884]	train-mlogloss:0.339235	test-mlogloss:0.521264
# [885]	train-mlogloss:0.339035	test-mlogloss:0.521236
# [886]	train-mlogloss:0.33886	test-mlogloss:0.521248
# [887]	train-mlogloss:0.33873	test-mlogloss:0.521256
# [888]	train-mlogloss:0.338591	test-mlogloss:0.521222
# [889]	train-mlogloss:0.338449	test-mlogloss:0.52122
# [890]	train-mlogloss:0.338306	test-mlogloss:0.521229
# [891]	train-mlogloss:0.338161	test-mlogloss:0.521239
# [892]	train-mlogloss:0.338064	test-mlogloss:0.521205
# [893]	train-mlogloss:0.337932	test-mlogloss:0.521195
# [894]	train-mlogloss:0.337834	test-mlogloss:0.521202
# [895]	train-mlogloss:0.337714	test-mlogloss:0.52121
# [896]	train-mlogloss:0.337587	test-mlogloss:0.521183
# [897]	train-mlogloss:0.337501	test-mlogloss:0.521171
# [898]	train-mlogloss:0.337327	test-mlogloss:0.521151
# [899]	train-mlogloss:0.337125	test-mlogloss:0.521183
# [900]	train-mlogloss:0.336981	test-mlogloss:0.521199
# [901]	train-mlogloss:0.336845	test-mlogloss:0.521207
# [902]	train-mlogloss:0.33671	test-mlogloss:0.521218
# [903]	train-mlogloss:0.336553	test-mlogloss:0.521206
# [904]	train-mlogloss:0.336392	test-mlogloss:0.521203
# [905]	train-mlogloss:0.336187	test-mlogloss:0.521201
# [906]	train-mlogloss:0.336032	test-mlogloss:0.521213
# [907]	train-mlogloss:0.335859	test-mlogloss:0.521185
# [908]	train-mlogloss:0.335708	test-mlogloss:0.521177
# [909]	train-mlogloss:0.335579	test-mlogloss:0.521172
# [910]	train-mlogloss:0.33544	test-mlogloss:0.521179
# [911]	train-mlogloss:0.335318	test-mlogloss:0.521161
# [912]	train-mlogloss:0.335141	test-mlogloss:0.521183
# [913]	train-mlogloss:0.335019	test-mlogloss:0.521174
# [914]	train-mlogloss:0.334897	test-mlogloss:0.521154
# [915]	train-mlogloss:0.334702	test-mlogloss:0.521177
# [916]	train-mlogloss:0.33456	test-mlogloss:0.521183
# [917]	train-mlogloss:0.334365	test-mlogloss:0.521171
# [918]	train-mlogloss:0.334213	test-mlogloss:0.521176
# Stopping. Best iteration:
# [898]	train-mlogloss:0.337327	test-mlogloss:0.521151
#
# [0.5211760462607925]

# %%
preds, model = runXGB(train_X, train_y, test_X, num_rounds=1000)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_starter2.csv", index=False)

# %% [markdown]
# If you think it's help, give me a vote.If you have problem, you can write you question in the comment. I will replay for you soon.

# %% [markdown]
# Edit:Many people use my script to change parameters.  The wrong way is to change learning rate and run_num blindly. When you adjust learning rate etc, you need  to adjust the best run_num according to  the cross validation. Otherwise, you will be overfitting.
